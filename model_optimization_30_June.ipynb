# %% [markdown]
# <a href="https://colab.research.google.com/github/yushendye/AerialInspection/blob/main/model_optimization_30_June.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cp /content/drive/MyDrive/modified_yolov4.zip /content/
# !cp /content/drive/MyDrive/updated_data.zip /content/

# %%
# !unzip /content/*.zip
# Out:
# Archive:  /content/modified_yolov4.zip
# caution: filename not matched:  /content/updated_data.zip

# %%
#!unzip /content/updated_data.zip
# !unzip /content/modified_yolov4.zip
# Out:
# Archive:  /content/modified_yolov4.zip
#    creating: content/tensorflow-yolov4-tflite/
#    creating: content/tensorflow-yolov4-tflite/scripts/
#   inflating: content/tensorflow-yolov4-tflite/scripts/get_coco_dataset_2017.sh
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc_annotation.py
#    creating: content/tensorflow-yolov4-tflite/scripts/voc/
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc/voc_make_names.py
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc/README.md
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc/voc_convert.py
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc/get_voc2012.sh
#   inflating: content/tensorflow-yolov4-tflite/scripts/google_utils.py
#   inflating: content/tensorflow-yolov4-tflite/scripts/coco_convert.py
#   inflating: content/tensorflow-yolov4-tflite/scripts/coco_annotation.py
#    creating: content/tensorflow-yolov4-tflite/.git/
#    creating: content/tensorflow-yolov4-tflite/.git/objects/
# ...

# %%
# !python /content/content/tensorflow-yolov4-tflite/train.py --weights /content/drive/MyDrive/backup/yolov4-obj_best.weights
# Out:
# Streaming output truncated to the last 5000 lines.
# => STEP 4030/8960   lr: 0.000623   giou_loss: 2.89   conf_loss: 1.84   prob_loss: 0.73   total_loss: 5.46
# => STEP 4031/8960   lr: 0.000623   giou_loss: 3.39   conf_loss: 1.88   prob_loss: 0.36   total_loss: 5.63
# => STEP 4032/8960   lr: 0.000623   giou_loss: 2.36   conf_loss: 1.60   prob_loss: 1.15   total_loss: 5.11
# => TEST STEP 4033   giou_loss: 4.36   conf_loss: 2.24   prob_loss: 0.94   total_loss: 7.54
# => TEST STEP 4033   giou_loss: 4.00   conf_loss: 2.56   prob_loss: 1.88   total_loss: 8.44
# => TEST STEP 4033   giou_loss: 3.20   conf_loss: 2.04   prob_loss: 4.07   total_loss: 9.31
# => STEP 4033/8960   lr: 0.000623   giou_loss: 2.64   conf_loss: 1.72   prob_loss: 0.56   total_loss: 4.91
# => STEP 4034/8960   lr: 0.000623   giou_loss: 1.13   conf_loss: 1.05   prob_loss: 1.25   total_loss: 3.43
# => STEP 4035/8960   lr: 0.000623   giou_loss: 1.51   conf_loss: 1.01   prob_loss: 0.45   total_loss: 2.97
# ...

# %%
# !cp -r /content/Modified /content/drive/MyDrive/30_June_Wts/

# %%
# !python /content/content/tensorflow-yolov4-tflite/save_model.py --weights /content/drive/MyDrive/backup/yolov4-obj_best.weights --output /content/30_June/
# Out:
# 2021-06-30 07:49:52.929347: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-30 07:49:54.419528: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-30 07:49:54.450759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-30 07:49:54.451338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-30 07:49:54.451379: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !rm /content/30_June/variables/variables.data-00000-of-00001
# !rm /content/30_June/variables/variables.index

# !cp /content/Modified/modified_wt.pb.data-00000-of-00001 /content/30_June/variables/
# !cp /content/Modified/modified_wt.pb.index /content/30_June/variables/

# %%
# !python /content/content/tensorflow-yolov4-tflite/detect.py --weights /content/30_June --output /content/out1.jpg --images /content/drive/MyDrive/umbrella/COCO_train2014_000000032997.jpg
# Out:
# 2021-06-30 07:55:51.682905: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-30 07:55:52.847031: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-30 07:55:52.874626: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-30 07:55:52.875203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-30 07:55:52.875246: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !wget https://cdn.thewire.in/wp-content/uploads/2020/12/19163218/India_Farming.jpg
# Out:
# --2021-06-30 08:00:27--  https://cdn.thewire.in/wp-content/uploads/2020/12/19163218/India_Farming.jpg
# Resolving cdn.thewire.in (cdn.thewire.in)... 104.21.15.201, 172.67.206.230, 2606:4700:3035::ac43:cee6, ...
# Connecting to cdn.thewire.in (cdn.thewire.in)|104.21.15.201|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 216970 (212K) [image/jpeg]
# Saving to: ‘India_Farming.jpg’
#
# India_Farming.jpg   100%[===================>] 211.88K   460KB/s    in 0.5s
#
# 2021-06-30 08:00:29 (460 KB/s) - ‘India_Farming.jpg’ saved [216970/216970]

# %%
# !python /content/content/tensorflow-yolov4-tflite/detect.py --weights /content/30_June --output /content/out2.jpg --images /content/India_Farming.jpg
# Out:
# 2021-06-30 08:00:57.882285: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-30 08:00:59.026364: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-30 08:00:59.058823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-30 08:00:59.059409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-30 08:00:59.059450: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !python /content/content/tensorflow-yolov4-tflite/detect.py --weights /content/30_June --output /content/out2.jpg --images /content/content/data/test/COCO_train2014_000000180387.jpg
# Out:
# 2021-06-30 08:03:34.455849: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-30 08:03:35.641486: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-30 08:03:35.675357: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-30 08:03:35.675953: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-30 08:03:35.676000: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !python /content/content/tensorflow-yolov4-tflite/detect.py --weights /content/30_June --output /content/out4.jpg --images /content/content/data/test/COCO_train2014_000000180389.jpg
# Out:
# 2021-06-30 08:04:15.557572: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-30 08:04:16.699338: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-30 08:04:16.729074: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-30 08:04:16.729674: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-30 08:04:16.729714: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !python /content/content/tensorflow-yolov4-tflite/detect_video.py --weights /content/30_June --output /content/vi_out_30_june1.mp4 --video /content/drive/MyDrive/videoplayback.mp4
# Out:
# 2021-06-30 08:07:34.042482: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-30 08:07:35.209368: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-30 08:07:35.243177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-30 08:07:35.243791: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-30 08:07:35.243840: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !python /content/content/tensorflow-yolov4-tflite/detect_video.py --weights /content/30_June --output /content/vi_out_30_june2.mp4 --video /content/drive/MyDrive/videoplayback2.mp4
# Out:
# 2021-06-30 08:08:31.998418: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-06-30 08:08:33.137988: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-06-30 08:08:33.166086: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-30 08:08:33.166668: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-30 08:08:33.166712: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# ...

# %%
# !cp /content/vi_out_30_june2.mp4 /content/drive/MyDrive/
