# %% [markdown]
# <a href="https://colab.research.google.com/github/yushendye/AerialInspection/blob/main/PP_YOLO_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cp /content/drive/MyDrive/modified_yolov4.zip /content/
# !unzip /content/modified_yolov4.zip
# Out:
# Archive:  /content/modified_yolov4.zip
#    creating: content/tensorflow-yolov4-tflite/
#    creating: content/tensorflow-yolov4-tflite/scripts/
#   inflating: content/tensorflow-yolov4-tflite/scripts/get_coco_dataset_2017.sh
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc_annotation.py
#    creating: content/tensorflow-yolov4-tflite/scripts/voc/
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc/voc_make_names.py
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc/README.md
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc/voc_convert.py
#   inflating: content/tensorflow-yolov4-tflite/scripts/voc/get_voc2012.sh
#   inflating: content/tensorflow-yolov4-tflite/scripts/google_utils.py
#   inflating: content/tensorflow-yolov4-tflite/scripts/coco_convert.py
#   inflating: content/tensorflow-yolov4-tflite/scripts/coco_annotation.py
#    creating: content/tensorflow-yolov4-tflite/.git/
#    creating: content/tensorflow-yolov4-tflite/.git/objects/
# ...

# %%
# !touch train_pp_yolo.py

# %%
# !cp /content/drive/MyDrive/updated_data.zip /content/
# !unzip /content/updated_data.zip
# Out:
# Archive:  /content/updated_data.zip
#    creating: content/data/
#   inflating: content/data/train.txt
#    creating: content/data/obj/
#   inflating: content/data/obj/COCO_train2014_000000303133.jpg
#   inflating: content/data/obj/COCO_train2014_000000475763.jpg
#   inflating: content/data/obj/COCO_train2014_000000115342.txt
#   inflating: content/data/obj/COCO_train2014_000000114732.jpg
#   inflating: content/data/obj/COCO_train2014_000000565444.jpg
#   inflating: content/data/obj/COCO_train2014_000000483956.txt
#   inflating: content/data/obj/COCO_train2014_000000524881.txt
#   inflating: content/data/obj/COCO_train2014_000000106799.txt
#   inflating: content/data/obj/COCO_train2014_000000057663.jpg
#   inflating: content/data/obj/COCO_train2014_000000049801.jpg
#   inflating: content/data/obj/COCO_train2014_000000131245.txt
#   inflating: content/data/obj/COCO_train2014_000000385448.txt
#   inflating: content/data/obj/COCO_train2014_000000541327.txt
# ...

# %%
# !mv /content/train_pp_yolo.py /content/content/tensorflow-yolov4-tflite

# %%
# !python /content/content/tensorflow-yolov4-tflite/train_pp_yolo.py
# Out:
# Traceback (most recent call last):
#   File "/content/content/tensorflow-yolov4-tflite/train_pp_yolo.py", line 160, in <module>
#     app.run(main)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/content/content/tensorflow-yolov4-tflite/train_pp_yolo.py", line 153, in main
#     train_step(image_data, target)
#   File "/content/content/tensorflow-yolov4-tflite/train_pp_yolo.py", line 96, in train_step
#     gradients = tape.gradient(total_loss, model.trainable_variables)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/backprop.py", line 1080, in gradient
#     unconnected_gradients=unconnected_gradients)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/imperative_grad.py", line 77, in imperative_grad
#     compat.as_str(unconnected_gradients.value))
# ...

# %%
# %cd /content/content/
# !zip -r ppyolo.zip tensorflow-yolov4-tflite
# Out:
# /content/content
#   adding: tensorflow-yolov4-tflite/ (stored 0%)
#   adding: tensorflow-yolov4-tflite/evaluate.py (deflated 69%)
#   adding: tensorflow-yolov4-tflite/CODE_OF_CONDUCT.md (deflated 55%)
#   adding: tensorflow-yolov4-tflite/README.md (deflated 71%)
#   adding: tensorflow-yolov4-tflite/core/ (stored 0%)
#   adding: tensorflow-yolov4-tflite/core/dataset.py (deflated 80%)
#   adding: tensorflow-yolov4-tflite/core/backbone.py (deflated 90%)
#   adding: tensorflow-yolov4-tflite/core/utils.py (deflated 75%)
#   adding: tensorflow-yolov4-tflite/core/__pycache__/ (stored 0%)
#   adding: tensorflow-yolov4-tflite/core/__pycache__/common.cpython-37.pyc (deflated 41%)
#   adding: tensorflow-yolov4-tflite/core/__pycache__/backbone.cpython-37.pyc (deflated 66%)
#   adding: tensorflow-yolov4-tflite/core/__pycache__/config.cpython-37.pyc (deflated 37%)
#   adding: tensorflow-yolov4-tflite/core/__pycache__/dataset.cpython-37.pyc (deflated 51%)
# ...

# %%
# !cp /content/content/ppyolo.zip /content/drive/MyDrive/
